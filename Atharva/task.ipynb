# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('production_analysis_dataset.csv')
df.sample(10)
# Out:
#     production_id product_category  factory    shift supervisor  \
# 1             102       Automotive  Plant_A    Night         S2
# 5             106      Electronics  Plant_B  Morning         S2
# 42            143        Furniture  Plant_C    Night         S2
# 0             101       Automotive  Plant_A    Night         S1
# 47            148       Automotive  Plant_A  Evening         S1
# 13            114        Furniture  Plant_C  Evening         S1
# 15            116       Automotive  Plant_A  Morning         S3
# 27            128        Furniture  Plant_A  Morning         S4
# 23            124        Furniture  Plant_A  Evening         S4
# 32            133        Furniture  Plant_A    Night         S3
#
#     units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 1              602               32                6.60                 0.32
# 5              621               28                8.23                 1.12
# ...

# %%
df.groupby('product_category')['units_produced'].sum()
# Out:
# product_category
# Automotive     9408
# Electronics    7491
# Furniture      7251
# Name: units_produced, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   production_id           50 non-null     int64
#  1   product_category        50 non-null     object
#  2   factory                 50 non-null     object
#  3   shift                   50 non-null     object
#  4   supervisor              50 non-null     object
#  5   units_produced          50 non-null     int64
#  6   defective_units         50 non-null     int64
#  7   production_time_hr      50 non-null     float64
#  8   machine_downtime_hr     50 non-null     float64
#  9   energy_consumption_kwh  50 non-null     int64
#  10  profit                  50 non-null     int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 4.4+ KB

# %%
df.groupby('factory')['profit'].mean()
# Out:
# factory
# Plant_A    18044.375000
# Plant_B    16973.384615
# Plant_C    18086.076923
# Name: profit, dtype: float64

# %%
df.groupby('shift')['defective_units'].sum()
# Out:
# shift
# Evening    132
# Morning    472
# Night      471
# Name: defective_units, dtype: int64

# %%
df.head()
# Out:
#    production_id product_category  factory    shift supervisor  \
# 0            101       Automotive  Plant_A    Night         S1
# 1            102       Automotive  Plant_A    Night         S2
# 2            103      Electronics  Plant_A    Night         S4
# 3            104      Electronics  Plant_B  Morning         S3
# 4            105        Furniture  Plant_A    Night         S3
#
#    units_produced  defective_units  production_time_hr  machine_downtime_hr  \
# 0             627               12                6.58                 0.56
# 1             602               32                6.60                 0.32
# 2             666               39                7.76                 0.78
# 3             474               22                6.97                 1.44
# 4             476               21                8.92                 1.15
#
#    energy_consumption_kwh  profit
# 0                    1028   12286
# 1                    1038   18279
# ...

# %%
df.groupby('supervisor')['production_time_hr'].mean()
# Out:
# supervisor
# S1    7.801818
# S2    7.450000
# S3    7.882000
# S4    7.956154
# Name: production_time_hr, dtype: float64

# %%
df.groupby(['factory','shift'])['energy_consumption_kwh'].sum()
# Out:
# factory  shift
# Plant_A  Evening     3330
#          Morning    11144
#          Night      12913
# Plant_B  Evening     2889
#          Morning     7923
#          Night       4981
# Plant_C  Evening     2214
#          Morning     5632
#          Night       7363
# Name: energy_consumption_kwh, dtype: int64

# %%
df.groupby('product_category').agg(['sum','max','min','mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\ProgramData\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
# ...
